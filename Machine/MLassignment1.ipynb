# %%
import os
import pandas as pd
df = pd.read_csv('C:\\Users\\msi\\Desktop\\ML\\cars.csv')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin
# 0            70     USA
# 1            70     USA
# 2            70     USA
# 3            70     USA
# ...

# %% [markdown]
# The table above shows there are 8 features :mpg , cylinders , displacement , horsepower , weight , acceleration , model_year , origin
# and 398 example.

# %%
import os
import pandas as pd
df = pd.read_csv('C:\\Users\\msi\\Desktop\\ML\\cars.csv')
df.isnull().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower       True
# weight          False
# acceleration    False
# model_year      False
# origin           True
# dtype: bool

# %% [markdown]
# There is one or more missing values in 2 features : horsepower , origin.

# %%
import os
import pandas as pd
df = pd.read_csv('C:\\Users\\msi\\Desktop\\ML\\cars.csv')
df.isnull().any()
missingValues=['horsepower', 'origin']
for x in missingValues:
    counter=df[x].isnull().sum()
    print(f"number of missing values in {x}")
    print(counter)
# Out:
# number of missing values in horsepower
# 6
# number of missing values in origin
# 2

# %% [markdown]
# There are 6 missing values in horsepower and 2 missing values in origin.

# %%
import os
import pandas as pd
df = pd.read_csv('C:\\Users\\msi\\Desktop\\ML\\cars.csv')
df.isnull().any()
missingValues=['horsepower', 'origin']
for x in missingValues:
    counter=df[x].isnull().sum()
    print(f"number of missing values in {x}")
    print(counter)
fillOrigin='origin'
modeValue=df[fillOrigin].mode().iloc[0]
print(modeValue)
df[fillOrigin].fillna(modeValue,inplace=True)
# Out:
# number of missing values in horsepower
# 6
# number of missing values in origin
# 2
# USA

# %% [markdown]
# Since the origin is a categorical data so the mode is used to fill the missing data , and the value of the mode is (USA).

# %%
import os
import pandas as pd
df = pd.read_csv('C:\\Users\\msi\\Desktop\\ML\\cars.csv')
df.isnull().any()
missingValues=['horsepower', 'origin']
for x in missingValues:
    counter=df[x].isnull().sum()
    print(f"number of missing values in {x}")
    print(counter)
fillOrigin='origin'
modeValue=df[fillOrigin].mode().iloc[0]
print('Mode Value',modeValue)
df[fillOrigin].fillna(modeValue,inplace=True)

#to chrck if there are outliers 
upperLimit= df['horsepower'].mean() + 3*df['horsepower'].std()
lowerLimit= df['horsepower'].mean() - 3*df['horsepower'].std()
print('upper limit', upperLimit)
print('lower limit', lowerLimit)
df.loc[(df['horsepower'] > upperLimit) | (df['horsepower']< lowerLimit)]

#fill the missing values using median
medianValue=df['horsepower'].median()
print('Median Value ',medianValue)
df['horsepower'].fillna(medianValue,inplace=True)
# Out:
# number of missing values in horsepower
# 6
# number of missing values in origin
# 2
# USA
# upper limit 219.94286755358752
# lower limit -11.004092043383423
# Median Value  93.5

# %%
import os
import pandas as pd
df = pd.read_csv('C:\\Users\\msi\\Desktop\\ML\\cars.csv')
df.isnull().any()
missingValues=['horsepower', 'origin']

#find the number of missing value in each one
for x in missingValues:
    counter=df[x].isnull().sum()
    print(f"number of missing values in {x}")
    print(counter)

# fill the missing value in origin using mode
fillOrigin='origin'
modeValue=df[fillOrigin].mode().iloc[0]
print('Mode Value',modeValue)
df[fillOrigin].fillna(modeValue,inplace=True)

#to chrck if there are outliers 
upperLimit= df['horsepower'].mean() + 3*df['horsepower'].std()
lowerLimit= df['horsepower'].mean() - 3*df['horsepower'].std()
print('upper limit', upperLimit)
print('lower limit', lowerLimit)
df.loc[(df['horsepower'] > upperLimit) | (df['horsepower']< lowerLimit)]

#fill the missing values using median
medianValue=df['horsepower'].median()
print('Median Value ',medianValue)
df['horsepower'].fillna(medianValue,inplace=True)
# Out:
# number of missing values in horsepower
# 6
# number of missing values in origin
# 2
# Mode Value USA
# upper limit 219.94286755358752
# lower limit -11.004092043383423
# Median Value  93.5

# %% [markdown]
# In the above code, the horsepower feature is an numarical feature and since there are outliers (using the Z-score to check about the outliers, based on 3 standard deviations the upper an the lower limit is calculated) the mean is not suitable , so the median is calculated to fill the missing values.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('C:\\Users\\msi\\Desktop\\ML\\cars.csv')
df.isnull().any()
missingValues=['horsepower', 'origin']

#find the number of missing value in each one
for x in missingValues:
    counter=df[x].isnull().sum()
    print(f"number of missing values in {x}")
    print(counter)

# fill the missing value in origin using mode
fillOrigin='origin'
modeValue=df[fillOrigin].mode().iloc[0]
print('Mode Value',modeValue)
df[fillOrigin].fillna(modeValue,inplace=True)

#to chrck if there are outliers 
upperLimit= df['horsepower'].mean() + 3*df['horsepower'].std()
lowerLimit= df['horsepower'].mean() - 3*df['horsepower'].std()
print('upper limit', upperLimit)
print('lower limit', lowerLimit)
df.loc[(df['horsepower'] > upperLimit) | (df['horsepower']< lowerLimit)]

#fill the missing values using median
medianValue=df['horsepower'].median()
print('Median Value ',medianValue)
df['horsepower'].fillna(medianValue,inplace=True)

#plot box plot
feature1 = 'mpg'
feature2 = 'origin'
df.boxplot(column=[feature1], by=feature2, grid=False)
plt.title('Box Plot of {} by {}'.format(feature1, feature2))
plt.xlabel(feature2)
plt.ylabel(feature1)
plt.show()
# Out:
# number of missing values in horsepower
# 6
# number of missing values in origin
# 2
# Mode Value USA
# upper limit 219.94286755358752
# lower limit -11.004092043383423
# Median Value  93.5

# %% [markdown]
# based on the plot above , Asis produces cars with better fuel economy

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('C:\\Users\\msi\\Desktop\\ML\\cars.csv')
df.isnull().any()
missingValues=['horsepower', 'origin']

#find the number of missing value in each one
for x in missingValues:
    counter=df[x].isnull().sum()
    print(f"number of missing values in {x}")
    print(counter)

# fill the missing value in origin using mode
fillOrigin='origin'
modeValue=df[fillOrigin].mode().iloc[0]
print('Mode Value',modeValue)
df[fillOrigin].fillna(modeValue,inplace=True)

#to chrck if there are outliers 
upperLimit= df['horsepower'].mean() + 3*df['horsepower'].std()
lowerLimit= df['horsepower'].mean() - 3*df['horsepower'].std()
print('upper limit', upperLimit)
print('lower limit', lowerLimit)
df.loc[(df['horsepower'] > upperLimit) | (df['horsepower']< lowerLimit)]

#fill the missing values using median
medianValue=df['horsepower'].median()
print('Median Value ',medianValue)
df['horsepower'].fillna(medianValue,inplace=True)

#plot the histogram 
feature1='mpg'
feature2='horsepower'
feature3='acceleration'

plt.hist(df[feature1], bins=20, color='purple', edgecolor='black')
plt.title('Histogram of {}'.format(feature1))
plt.xlabel(feature1)
plt.ylabel('Frequency')
plt.figure(figsize=(2, 2))
plt.show()

plt.hist(df[feature2], bins=20, color='green', edgecolor='black')
plt.title('Histogram of {}'.format(feature2))
plt.xlabel(feature2)
plt.ylabel('Frequency')
plt.figure(figsize=(2, 2))
plt.show()

plt.hist(df[feature3], bins=20, color='pink', edgecolor='black')
plt.title('Histogram of {}'.format(feature3))
plt.xlabel(feature3)
plt.ylabel('Frequency')
plt.figure(figsize=(2, 2))
plt.show()
# Out:
# number of missing values in horsepower
# 6
# number of missing values in origin
# 2
# Mode Value USA
# upper limit 219.94286755358752
# lower limit -11.004092043383423
# Median Value  93.5

# %% [markdown]
# I think acceleration , to justify the answer:

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('C:\\Users\\msi\\Desktop\\ML\\cars.csv')
df.isnull().any()
missingValues=['horsepower', 'origin']

#find the number of missing value in each one
for x in missingValues:
    counter=df[x].isnull().sum()
    print(f"number of missing values in {x}")
    print(counter)

# fill the missing value in origin using mode
fillOrigin='origin'
modeValue=df[fillOrigin].mode().iloc[0]
print('Mode Value',modeValue)
df[fillOrigin].fillna(modeValue,inplace=True)

#to chrck if there are outliers 
upperLimit= df['horsepower'].mean() + 3*df['horsepower'].std()
lowerLimit= df['horsepower'].mean() - 3*df['horsepower'].std()
print('upper limit', upperLimit)
print('lower limit', lowerLimit)
df.loc[(df['horsepower'] > upperLimit) | (df['horsepower']< lowerLimit)]

#fill the missing values using median
medianValue=df['horsepower'].median()
print('Median Value ',medianValue)
df['horsepower'].fillna(medianValue,inplace=True)

features=['mpg' , 'horsepower' , 'acceleration']
for f in features:
     std_dev = np.std(df[f])
     print(f'{f}: Std Dev={std_dev:.2f}')
# Out:
# number of missing values in horsepower
# 6
# number of missing values in origin
# 2
# Mode Value USA
# upper limit 219.94286755358752
# lower limit -11.004092043383423
# Median Value  93.5
# mpg: Std Dev=7.81
# horsepower: Std Dev=38.17
# acceleration: Std Dev=2.75

# %% [markdown]
# The standard deviation for the mpg = 7.81 , horsepower=38.17 and acceleration =2.75 , the lower standard deviation indicates less variability in the data.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('C:\\Users\\msi\\Desktop\\ML\\cars.csv')
df.isnull().any()
missingValues=['horsepower', 'origin']

#find the number of missing value in each one
for x in missingValues:
    counter=df[x].isnull().sum()
    print(f"number of missing values in {x}")
    print(counter)

# fill the missing value in origin using mode
fillOrigin='origin'
modeValue=df[fillOrigin].mode().iloc[0]
print('Mode Value',modeValue)
df[fillOrigin].fillna(modeValue,inplace=True)

#to chrck if there are outliers 
upperLimit= df['horsepower'].mean() + 3*df['horsepower'].std()
lowerLimit= df['horsepower'].mean() - 3*df['horsepower'].std()
print('upper limit', upperLimit)
print('lower limit', lowerLimit)
df.loc[(df['horsepower'] > upperLimit) | (df['horsepower']< lowerLimit)]

#fill the missing values using median
medianValue=df['horsepower'].median()
print('Median Value ',medianValue)
df['horsepower'].fillna(medianValue,inplace=True)

firstFeature='mpg'
secondFeature='horsepower'
plt.scatter(df[firstFeature] ,df[secondFeature])
plt.title('scatter between {} and {}'.format(firstFeature,secondFeature))
plt.xlabel(secondFeature)
plt.ylabel(firstFeature)
plt.show()
# Out:
# number of missing values in horsepower
# 6
# number of missing values in origin
# 2
# Mode Value USA
# upper limit 219.94286755358752
# lower limit -11.004092043383423
# Median Value  93.5

# %% [markdown]
# Based on the plot above, there is a correlation between the 2 features and it is a negative correlation.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('C:\\Users\\msi\\Desktop\\ML\\cars.csv')
df.isnull().any()
missingValues=['horsepower', 'origin']

#find the number of missing value in each one
for x in missingValues:
    counter=df[x].isnull().sum()
    print(f"number of missing values in {x}")
    print(counter)

# fill the missing value in origin using mode
fillOrigin='origin'
modeValue=df[fillOrigin].mode().iloc[0]
print('Mode Value',modeValue)
df[fillOrigin].fillna(modeValue,inplace=True)

#to check if there are outliers 
upperLimit= df['horsepower'].mean() + 3*df['horsepower'].std()
lowerLimit= df['horsepower'].mean() - 3*df['horsepower'].std()
print('upper limit', upperLimit)
print('lower limit', lowerLimit)
df.loc[(df['horsepower'] > upperLimit) | (df['horsepower']< lowerLimit)]

#fill the missing values using median
medianValue=df['horsepower'].median()
print('Median Value ',medianValue)
df['horsepower'].fillna(medianValue,inplace=True)

x=df['mpg'].values
y=df['horsepower'].values
X = np.column_stack((np.ones_like(x), x))#x0=1
coefficients = np.linalg.inv(X.T @ X) @ X.T @ y
beta_0, beta_1 = coefficients
plt.scatter(x ,y,label='Scatter Plot')
plt.plot(x, beta_0 + beta_1 * x, color='green', label='Linear Regression Line')
plt.title('Linear Regression for mpg from horsepower')
plt.xlabel('horsepower')
plt.ylabel('mpg')
plt.legend()
plt.show()
# Out:
# number of missing values in horsepower
# 6
# number of missing values in origin
# 2
# Mode Value USA
# upper limit 219.94286755358752
# lower limit -11.004092043383423
# Median Value  93.5

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('C:\\Users\\msi\\Desktop\\ML\\cars.csv')
df.isnull().any()
missingValues=['horsepower', 'origin']

#find the number of missing value in each one
for x in missingValues:
    counter=df[x].isnull().sum()
    print(f"number of missing values in {x}")
    print(counter)

# fill the missing value in origin using mode
fillOrigin='origin'
modeValue=df[fillOrigin].mode().iloc[0]
print('Mode Value',modeValue)
df[fillOrigin].fillna(modeValue,inplace=True)

#to chrck if there are outliers 
upperLimit= df['horsepower'].mean() + 3*df['horsepower'].std()
lowerLimit= df['horsepower'].mean() - 3*df['horsepower'].std()
print('upper limit', upperLimit)
print('lower limit', lowerLimit)
df.loc[(df['horsepower'] > upperLimit) | (df['horsepower']< lowerLimit)]

#fill the missing values using median
medianValue=df['horsepower'].median()
print('Median Value ',medianValue)
df['horsepower'].fillna(medianValue,inplace=True)

x=df['mpg'].values
y=df['horsepower'].values
X = np.column_stack((np.ones_like(x), x, x**2))
coefficients = np.linalg.inv(X.T @ X) @ X.T @ y
w0, w1, w2 = coefficients
# Create a scatter plot
plt.scatter(x, y, label='Scatter Plot')
x_range = np.linspace(min(x), max(x), 100)
y_quad = w0 + w1 * x_range + w2 * (x_range**2)
plt.plot(x_range, y_quad, color='green', label='Quadratic Regression')
plt.xlabel('horsepower')
plt.ylabel('mpg')
plt.title('Quadratic Regression for mpg and horsepower')
plt.legend()
plt.show()
# Out:
# number of missing values in horsepower
# 6
# number of missing values in origin
# 2
# Mode Value USA
# upper limit 219.94286755358752
# lower limit -11.004092043383423
# Median Value  93.5

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('C:\\Users\\msi\\Desktop\\ML\\cars.csv')
df.isnull().any()
missingValues=['horsepower', 'origin']

#find the number of missing value in each one
for x in missingValues:
    counter=df[x].isnull().sum()

# fill the missing value in origin using mode
fillOrigin='origin'
modeValue=df[fillOrigin].mode().iloc[0]
df[fillOrigin].fillna(modeValue,inplace=True)

#to chrck if there are outliers 
upperLimit= df['horsepower'].mean() + 3*df['horsepower'].std()
lowerLimit= df['horsepower'].mean() - 3*df['horsepower'].std()
df.loc[(df['horsepower'] > upperLimit) | (df['horsepower']< lowerLimit)]

#fill the missing values using median
medianValue=df['horsepower'].median()
df['horsepower'].fillna(medianValue,inplace=True)

x=df['mpg'].values
y=df['horsepower'].values
learning_rate = 0.001 
th0 = 0.0
th1 = 0.0
epochs = 199999
numOfData = len(x)
for epoch in range(epochs):

    h = th0 + th1 * x
    gradient_0 = (1/numOfData) * np.sum(h - y)
    gradient_1 = (1/numOfData) * np.sum((h - y) * x)
    th0 -= learning_rate * gradient_0
    th1 -= learning_rate * gradient_1

plt.scatter(x, y, label='Scatter Plot')
plt.plot(x, th0 + th1 * x, color='pink', label='Gradient Descent ')
plt.title('Gradient Descent for Predicting mpg from horsepower')
plt.xlabel('horsepower')
plt.ylabel('mpg')
print('theta0-> {:.2f}'.format(th0))
print('theta1-> {:.2f}'.format(th1))
plt.legend()
plt.show()
# Out:
# theta0-> 193.25
# theta1-> -3.78
